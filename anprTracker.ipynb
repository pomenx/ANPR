# %%
from ultralytics import YOLO
import cv2
import numpy as np
import util
import matplotlib.pyplot as plt
from sort import *
from util import get_car, read_license_plate, write_csv


results = {}

mot_tracker = Sort()

# load models
coco_model = YOLO('yolov8n.pt')
license_plate_detector = YOLO('license_plate_detector.pt')

# load video
cap = cv2.VideoCapture('sample11.mp4')

vehicles = [2, 3, 5, 7]

# read frames
frame_nmr = -1
ret = True
while ret:
    frame_nmr += 1
    ret, frame = cap.read()
    if ret:
        results[frame_nmr] = {}
        # detect vehicles
        detections = coco_model(frame)[0]
        detections_ = []
        for detection in detections.boxes.data.tolist():
            x1, y1, x2, y2, score, class_id = detection
            if int(class_id) in vehicles:
                detections_.append([x1, y1, x2, y2, score])

        # track vehicles
        track_ids = mot_tracker.update(np.asarray(detections_))
        # detect license plates
        license_plates = license_plate_detector(frame)[0]
        for license_plate in license_plates.boxes.data.tolist():
            print("-----------plate detected------------")
            x1, y1, x2, y2, score, class_id = license_plate

            # assign license plate to car
            xcar1, ycar1, xcar2, ycar2, car_id = get_car(license_plate, track_ids)

            if car_id != -1:

                # crop license plate
                license_plate_crop = frame[int(y1):int(y2), int(x1): int(x2), :]

                # process license plate
                license_plate_crop_gray = cv2.cvtColor(license_plate_crop, cv2.COLOR_BGR2GRAY)
                _, license_plate_crop_thresh = cv2.threshold(license_plate_crop_gray, 64, 255, cv2.THRESH_BINARY_INV)

                # read license plate number
                license_plate_text, license_plate_text_score = read_license_plate(license_plate_crop_thresh)

                if license_plate_text is not None:
                    results[frame_nmr][car_id] = {'car': {'bbox': [xcar1, ycar1, xcar2, ycar2]},
                                                  'license_plate': {'bbox': [x1, y1, x2, y2],
                                                                    'text': license_plate_text,
                                                                    'bbox_score': score,
                                                                    'text_score': license_plate_text_score}}

# write results
write_csv(results, 'test.csv')
# Out:
# 0: 384x640 9 persons, 1 car, 10.3ms
# Speed: 2.5ms preprocess, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 1 car, 1 truck, 9.2ms
# Speed: 2.9ms preprocess, 9.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.1ms
# Speed: 2.4ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 1 car, 1 truck, 11.0ms
# Speed: 6.7ms preprocess, 11.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.6ms
# Speed: 2.4ms preprocess, 8.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 1 car, 1 truck, 14.6ms
# Speed: 3.0ms preprocess, 14.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 12.5ms
# Speed: 2.5ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 7 persons, 1 car, 1 truck, 11.3ms
# Speed: 2.6ms preprocess, 11.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.2ms
# Speed: 3.6ms preprocess, 8.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 8 persons, 1 truck, 9.9ms
# Speed: 2.8ms preprocess, 9.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.7ms
# Speed: 2.5ms preprocess, 7.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 8 persons, 1 car, 1 truck, 9.9ms
# Speed: 2.7ms preprocess, 9.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.4ms
# Speed: 2.5ms preprocess, 8.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 8 persons, 1 car, 1 truck, 9.9ms
# Speed: 2.6ms preprocess, 9.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.5ms
# Speed: 2.5ms preprocess, 8.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 7 persons, 1 car, 1 truck, 12.0ms
# Speed: 3.2ms preprocess, 12.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.1ms
# Speed: 4.3ms preprocess, 9.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 7 persons, 1 truck, 10.5ms
# Speed: 5.8ms preprocess, 10.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.9ms
# Speed: 2.9ms preprocess, 7.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 7 persons, 1 truck, 10.0ms
# Speed: 3.1ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.2ms
# Speed: 2.8ms preprocess, 8.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 7 persons, 1 truck, 15.1ms
# Speed: 2.6ms preprocess, 15.1ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 12.6ms
# Speed: 5.5ms preprocess, 12.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 7 persons, 1 car, 1 truck, 9.3ms
# Speed: 2.8ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.8ms
# Speed: 2.8ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 1 car, 1 truck, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.1ms
# Speed: 2.6ms preprocess, 8.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 car, 1 truck, 10.9ms
# Speed: 5.5ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.9ms
# Speed: 2.6ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 1 truck, 9.3ms
# Speed: 2.8ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.4ms
# Speed: 3.9ms preprocess, 8.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 car, 1 truck, 11.0ms
# Speed: 3.1ms preprocess, 11.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.1ms
# Speed: 2.5ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 1 car, 1 truck, 9.5ms
# Speed: 4.1ms preprocess, 9.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.7ms
# Speed: 2.9ms preprocess, 9.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 car, 1 truck, 9.1ms
# Speed: 4.4ms preprocess, 9.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.7ms
# Speed: 2.8ms preprocess, 8.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 8 persons, 1 truck, 9.5ms
# Speed: 3.2ms preprocess, 9.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.8ms
# Speed: 2.5ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 1 truck, 15.6ms
# Speed: 3.0ms preprocess, 15.6ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 11.6ms
# Speed: 17.1ms preprocess, 11.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 2 bicycles, 1 truck, 12.4ms
# Speed: 3.6ms preprocess, 12.4ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.8ms
# Speed: 2.5ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 1 truck, 18.5ms
# Speed: 2.8ms preprocess, 18.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 10.4ms
# Speed: 2.5ms preprocess, 10.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 bicycle, 1 car, 1 truck, 12.4ms
# Speed: 2.8ms preprocess, 12.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 13.8ms
# Speed: 5.5ms preprocess, 13.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 car, 1 truck, 11.0ms
# Speed: 2.9ms preprocess, 11.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.7ms
# Speed: 3.4ms preprocess, 7.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 8 persons, 1 car, 1 truck, 10.0ms
# Speed: 5.4ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.8ms
# Speed: 2.7ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 1 bicycle, 1 car, 1 truck, 9.3ms
# Speed: 3.3ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.3ms
# Speed: 2.6ms preprocess, 8.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 1 car, 1 truck, 10.3ms
# Speed: 2.7ms preprocess, 10.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.6ms
# Speed: 2.5ms preprocess, 9.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 truck, 9.3ms
# Speed: 2.8ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.8ms
# Speed: 3.1ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 bicycle, 1 truck, 8.9ms
# Speed: 3.0ms preprocess, 8.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 21.7ms
# Speed: 2.6ms preprocess, 21.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 bicycle, 1 truck, 9.6ms
# Speed: 2.6ms preprocess, 9.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.0ms
# Speed: 2.4ms preprocess, 9.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 2 bicycles, 1 truck, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 15.1ms
# Speed: 2.4ms preprocess, 15.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 2 bicycles, 1 truck, 9.2ms
# Speed: 4.0ms preprocess, 9.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.0ms
# Speed: 4.0ms preprocess, 8.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 truck, 9.4ms
# Speed: 2.9ms preprocess, 9.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.0ms
# Speed: 2.7ms preprocess, 8.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 truck, 9.8ms
# Speed: 2.6ms preprocess, 9.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.1ms
# Speed: 2.4ms preprocess, 9.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 1 truck, 9.6ms
# Speed: 5.6ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.6ms
# Speed: 2.5ms preprocess, 8.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 1 truck, 10.2ms
# Speed: 2.6ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.4ms
# Speed: 2.5ms preprocess, 9.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 bicycle, 1 car, 1 truck, 9.4ms
# Speed: 2.5ms preprocess, 9.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.8ms
# Speed: 2.4ms preprocess, 8.8ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 2 cars, 1 truck, 9.9ms
# Speed: 2.8ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.9ms
# Speed: 2.4ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 1 bicycle, 1 truck, 9.9ms
# Speed: 2.6ms preprocess, 9.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 10.2ms
# Speed: 2.4ms preprocess, 10.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 car, 1 truck, 15.6ms
# Speed: 2.6ms preprocess, 15.6ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.8ms
# Speed: 2.4ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 car, 1 truck, 9.8ms
# Speed: 2.9ms preprocess, 9.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.7ms
# Speed: 2.4ms preprocess, 7.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 car, 1 truck, 11.6ms
# Speed: 2.7ms preprocess, 11.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.6ms
# Speed: 2.3ms preprocess, 9.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 1 car, 1 truck, 9.5ms
# Speed: 2.8ms preprocess, 9.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.2ms
# Speed: 2.4ms preprocess, 8.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 12 persons, 1 car, 1 truck, 9.4ms
# Speed: 2.4ms preprocess, 9.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.7ms
# Speed: 2.6ms preprocess, 7.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 car, 1 truck, 11.9ms
# Speed: 2.5ms preprocess, 11.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.2ms
# Speed: 2.6ms preprocess, 8.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 12 persons, 1 car, 1 truck, 1 frisbee, 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.1ms
# Speed: 2.4ms preprocess, 9.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 bicycle, 1 truck, 11.2ms
# Speed: 6.3ms preprocess, 11.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 16.9ms
# Speed: 6.1ms preprocess, 16.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 1 car, 1 truck, 14.4ms
# Speed: 2.7ms preprocess, 14.4ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 17.4ms
# Speed: 5.0ms preprocess, 17.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 13 persons, 1 car, 1 truck, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 13.3ms
# Speed: 5.2ms preprocess, 13.3ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 12 persons, 1 truck, 25.1ms
# Speed: 2.8ms preprocess, 25.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 10.6ms
# Speed: 4.4ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 13 persons, 1 bicycle, 1 car, 1 truck, 10.8ms
# Speed: 2.7ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 18.4ms
# Speed: 4.6ms preprocess, 18.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 1 truck, 16.9ms
# Speed: 2.8ms preprocess, 16.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 12.2ms
# Speed: 5.4ms preprocess, 12.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 12 persons, 1 truck, 11.6ms
# Speed: 4.7ms preprocess, 11.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 11.1ms
# Speed: 4.1ms preprocess, 11.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 bicycle, 1 truck, 11.2ms
# Speed: 3.6ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 19.2ms
# Speed: 5.3ms preprocess, 19.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 1 bicycle, 1 truck, 9.8ms
# Speed: 3.0ms preprocess, 9.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.3ms
# Speed: 4.5ms preprocess, 8.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 truck, 9.8ms
# Speed: 2.9ms preprocess, 9.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.0ms
# Speed: 2.6ms preprocess, 9.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 truck, 9.6ms
# Speed: 2.5ms preprocess, 9.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.8ms
# Speed: 2.4ms preprocess, 9.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 1 truck, 10.3ms
# Speed: 3.2ms preprocess, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.1ms
# Speed: 2.6ms preprocess, 8.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 1 car, 1 truck, 9.5ms
# Speed: 3.5ms preprocess, 9.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.5ms
# Speed: 3.1ms preprocess, 8.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 1 car, 1 truck, 9.3ms
# Speed: 3.7ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.9ms
# Speed: 2.9ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 1 car, 1 truck, 11.1ms
# Speed: 2.7ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.8ms
# Speed: 3.2ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 1 truck, 11.4ms
# Speed: 2.8ms preprocess, 11.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.7ms
# Speed: 3.3ms preprocess, 7.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 1 truck, 9.2ms
# Speed: 2.8ms preprocess, 9.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.8ms
# Speed: 2.9ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 13 persons, 1 truck, 10.2ms
# Speed: 4.3ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 12 persons, 1 truck, 9.9ms
# Speed: 3.0ms preprocess, 9.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.1ms
# Speed: 3.1ms preprocess, 8.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 13 persons, 1 truck, 9.7ms
# Speed: 2.9ms preprocess, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.8ms
# Speed: 3.1ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 12 persons, 1 truck, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.4ms
# Speed: 3.2ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 1 truck, 10.1ms
# Speed: 4.1ms preprocess, 10.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.7ms
# Speed: 3.4ms preprocess, 8.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 14 persons, 1 truck, 10.1ms
# Speed: 3.5ms preprocess, 10.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.2ms
# Speed: 3.0ms preprocess, 8.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 1 truck, 10.0ms
# Speed: 2.9ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.9ms
# Speed: 2.6ms preprocess, 9.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 1 truck, 10.3ms
# Speed: 2.9ms preprocess, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.1ms
# Speed: 2.9ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 14 persons, 1 truck, 9.9ms
# Speed: 3.4ms preprocess, 9.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.5ms
# Speed: 2.7ms preprocess, 8.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 12 persons, 1 car, 1 truck, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.3ms
# Speed: 2.4ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 12 persons, 1 car, 1 truck, 11.9ms
# Speed: 8.5ms preprocess, 11.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.6ms
# Speed: 3.4ms preprocess, 8.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 12 persons, 1 car, 1 truck, 9.2ms
# Speed: 10.6ms preprocess, 9.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.9ms
# Speed: 3.1ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 car, 1 truck, 18.7ms
# Speed: 3.6ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.8ms
# Speed: 3.9ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 bicycle, 2 cars, 1 truck, 10.2ms
# Speed: 5.1ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.0ms
# Speed: 2.4ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 1 bicycle, 2 cars, 1 truck, 9.8ms
# Speed: 3.1ms preprocess, 9.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 12.4ms
# Speed: 2.8ms preprocess, 12.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 13 persons, 1 bicycle, 1 car, 10.2ms
# Speed: 3.9ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.9ms
# Speed: 6.4ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 12 persons, 1 bicycle, 1 car, 9.7ms
# Speed: 3.0ms preprocess, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.4ms
# Speed: 2.9ms preprocess, 8.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 1 bicycle, 2 cars, 9.6ms
# Speed: 2.9ms preprocess, 9.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.6ms
# Speed: 2.4ms preprocess, 7.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 12 persons, 1 bicycle, 1 car, 9.8ms
# Speed: 2.8ms preprocess, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.1ms
# Speed: 2.5ms preprocess, 9.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 1 bicycle, 3 cars, 9.3ms
# Speed: 2.9ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.5ms
# Speed: 3.1ms preprocess, 9.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 2 cars, 11.2ms
# Speed: 3.0ms preprocess, 11.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.2ms
# Speed: 3.2ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 2 cars, 9.1ms
# Speed: 3.7ms preprocess, 9.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.8ms
# Speed: 2.9ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 14 persons, 3 cars, 10.4ms
# Speed: 2.8ms preprocess, 10.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.9ms
# Speed: 3.7ms preprocess, 7.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 2 cars, 10.6ms
# Speed: 3.1ms preprocess, 10.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.7ms
# Speed: 2.8ms preprocess, 9.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 6 persons, 2 cars, 10.4ms
# Speed: 3.0ms preprocess, 10.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.1ms
# Speed: 2.5ms preprocess, 10.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 9.8ms
# Speed: 2.8ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.1ms
# Speed: 2.6ms preprocess, 15.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 13.3ms
# Speed: 2.8ms preprocess, 13.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.8ms
# Speed: 4.0ms preprocess, 7.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 17.1ms
# Speed: 7.8ms preprocess, 17.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.2ms
# Speed: 2.5ms preprocess, 9.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 backpack, 11.4ms
# Speed: 2.6ms preprocess, 11.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.5ms
# Speed: 2.7ms preprocess, 9.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 backpack, 9.6ms
# Speed: 2.7ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.1ms
# Speed: 2.5ms preprocess, 9.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 backpack, 10.5ms
# Speed: 2.7ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.3ms
# Speed: 2.4ms preprocess, 15.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 dog, 1 backpack, 9.8ms
# Speed: 2.7ms preprocess, 9.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.1ms
# Speed: 2.5ms preprocess, 12.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 car, 1 backpack, 13.1ms
# Speed: 2.6ms preprocess, 13.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.5ms
# Speed: 2.5ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 8.9ms
# Speed: 2.5ms preprocess, 8.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.2ms
# Speed: 2.4ms preprocess, 8.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 cars, 16.0ms
# Speed: 5.5ms preprocess, 16.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.0ms
# Speed: 2.6ms preprocess, 8.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 cars, 9.3ms
# Speed: 2.5ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.6ms
# Speed: 2.6ms preprocess, 15.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 13.2ms
# Speed: 2.6ms preprocess, 13.2ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.3ms
# Speed: 2.7ms preprocess, 8.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 13.7ms
# Speed: 2.8ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.9ms
# Speed: 2.7ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 15.9ms
# Speed: 2.5ms preprocess, 15.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.0ms
# Speed: 2.5ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 8.4ms
# Speed: 2.5ms preprocess, 8.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.0ms
# Speed: 2.7ms preprocess, 12.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 16.3ms
# Speed: 5.0ms preprocess, 16.3ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.0ms
# Speed: 2.4ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 2 cars, 11.9ms
# Speed: 2.5ms preprocess, 11.9ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.2ms
# Speed: 2.4ms preprocess, 9.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 3 cars, 28.8ms
# Speed: 2.7ms preprocess, 28.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.1ms
# Speed: 2.7ms preprocess, 8.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 4 cars, 19.8ms
# Speed: 2.6ms preprocess, 19.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.8ms
# Speed: 2.8ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 2 cars, 1 train, 15.2ms
# Speed: 3.2ms preprocess, 15.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.3ms
# Speed: 2.5ms preprocess, 8.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 8 persons, 2 cars, 17.9ms
# Speed: 2.4ms preprocess, 17.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.9ms
# Speed: 2.7ms preprocess, 7.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 2 cars, 21.5ms
# Speed: 3.1ms preprocess, 21.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 15.8ms
# Speed: 2.9ms preprocess, 15.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 12 persons, 3 cars, 1 bus, 24.3ms
# Speed: 3.6ms preprocess, 24.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 13.8ms
# Speed: 6.1ms preprocess, 13.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 3 cars, 1 bus, 1 traffic light, 1 skateboard, 15.2ms
# Speed: 2.8ms preprocess, 15.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.5ms
# Speed: 3.4ms preprocess, 8.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 3 cars, 9.4ms
# Speed: 2.8ms preprocess, 9.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.9ms
# Speed: 2.8ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 13 persons, 3 cars, 23.8ms
# Speed: 2.4ms preprocess, 23.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.0ms
# Speed: 2.8ms preprocess, 8.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 1 bicycle, 3 cars, 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 13.7ms
# Speed: 2.5ms preprocess, 13.7ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 bicycle, 3 cars, 1 truck, 10.2ms
# Speed: 3.7ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.4ms
# Speed: 2.9ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 2 cars, 16.6ms
# Speed: 8.6ms preprocess, 16.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.7ms
# Speed: 2.8ms preprocess, 7.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 2 cars, 15.1ms
# Speed: 2.7ms preprocess, 15.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.6ms
# Speed: 2.4ms preprocess, 7.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 13 persons, 2 cars, 21.2ms
# Speed: 2.9ms preprocess, 21.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.4ms
# Speed: 2.8ms preprocess, 9.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 3 cars, 11.8ms
# Speed: 2.8ms preprocess, 11.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.7ms
# Speed: 3.1ms preprocess, 9.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 bicycle, 2 cars, 9.7ms
# Speed: 2.6ms preprocess, 9.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.0ms
# Speed: 2.4ms preprocess, 9.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 2 cars, 9.4ms
# Speed: 4.0ms preprocess, 9.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.4ms
# Speed: 2.7ms preprocess, 9.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 2 cars, 10.1ms
# Speed: 3.0ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.9ms
# Speed: 2.6ms preprocess, 8.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 12 persons, 1 bicycle, 2 cars, 10.0ms
# Speed: 2.9ms preprocess, 10.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.1ms
# Speed: 3.0ms preprocess, 8.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 2 cars, 10.4ms
# Speed: 2.8ms preprocess, 10.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 10.8ms
# Speed: 2.4ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 bicycle, 2 cars, 9.7ms
# Speed: 2.9ms preprocess, 9.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 18.1ms
# Speed: 2.5ms preprocess, 18.1ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 1 bicycle, 2 cars, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.3ms
# Speed: 3.9ms preprocess, 8.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 1 bicycle, 2 cars, 1 motorcycle, 10.4ms
# Speed: 3.2ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.3ms
# Speed: 2.5ms preprocess, 8.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 bicycle, 2 cars, 10.1ms
# Speed: 3.6ms preprocess, 10.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.7ms
# Speed: 2.6ms preprocess, 9.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 bicycle, 2 cars, 11.3ms
# Speed: 4.4ms preprocess, 11.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 10.3ms
# Speed: 2.5ms preprocess, 10.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 bicycle, 2 cars, 9.7ms
# Speed: 2.8ms preprocess, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.1ms
# Speed: 4.1ms preprocess, 8.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 1 bicycle, 2 cars, 10.1ms
# Speed: 2.9ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 11.3ms
# Speed: 2.4ms preprocess, 11.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 1 bicycle, 2 cars, 9.9ms
# Speed: 2.9ms preprocess, 9.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 10.7ms
# Speed: 3.1ms preprocess, 10.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 8 persons, 1 bicycle, 2 cars, 9.7ms
# Speed: 2.7ms preprocess, 9.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 12.0ms
# Speed: 2.4ms preprocess, 12.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 2 cars, 23.3ms
# Speed: 3.1ms preprocess, 23.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 13.2ms
# Speed: 2.6ms preprocess, 13.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 8 persons, 2 cars, 17.2ms
# Speed: 2.7ms preprocess, 17.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 16.7ms
# Speed: 5.1ms preprocess, 16.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 8 persons, 2 cars, 15.6ms
# Speed: 2.7ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.2ms
# Speed: 2.4ms preprocess, 8.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 8 persons, 2 cars, 1 truck, 17.6ms
# Speed: 2.6ms preprocess, 17.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 10.4ms
# Speed: 2.4ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 2 cars, 17.3ms
# Speed: 2.6ms preprocess, 17.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 13.5ms
# Speed: 2.6ms preprocess, 13.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 1 bicycle, 2 cars, 19.1ms
# Speed: 2.4ms preprocess, 19.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 14.7ms
# Speed: 4.5ms preprocess, 14.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 2 cars, 15.0ms
# Speed: 2.6ms preprocess, 15.0ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.0ms
# Speed: 2.7ms preprocess, 8.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 2 cars, 19.1ms
# Speed: 2.9ms preprocess, 19.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 14.9ms
# Speed: 2.4ms preprocess, 14.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 8 persons, 2 cars, 18.8ms
# Speed: 4.1ms preprocess, 18.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.2ms
# Speed: 2.3ms preprocess, 9.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 8 persons, 2 cars, 21.6ms
# Speed: 2.7ms preprocess, 21.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 11.0ms
# Speed: 2.5ms preprocess, 11.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 8 persons, 2 cars, 18.8ms
# Speed: 3.3ms preprocess, 18.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 13.7ms
# Speed: 3.0ms preprocess, 13.7ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 2 cars, 10.9ms
# Speed: 3.6ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 11.8ms
# Speed: 2.7ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 8 persons, 1 bicycle, 2 cars, 17.7ms
# Speed: 3.2ms preprocess, 17.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.9ms
# Speed: 2.8ms preprocess, 8.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 1 bicycle, 2 cars, 1 truck, 9.1ms
# Speed: 3.8ms preprocess, 9.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 10.2ms
# Speed: 2.9ms preprocess, 10.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 8 persons, 1 bicycle, 2 cars, 8.3ms
# Speed: 2.8ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.3ms
# Speed: 2.4ms preprocess, 8.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 1 bicycle, 3 cars, 11.9ms
# Speed: 2.5ms preprocess, 11.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.9ms
# Speed: 7.4ms preprocess, 9.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 8 persons, 2 cars, 15.5ms
# Speed: 2.4ms preprocess, 15.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 7 persons, 1 bicycle, 2 cars, 9.3ms
# Speed: 2.9ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.0ms
# Speed: 3.1ms preprocess, 8.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 2 cars, 10.2ms
# Speed: 3.3ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.8ms
# Speed: 2.4ms preprocess, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 7 persons, 2 cars, 11.5ms
# Speed: 3.3ms preprocess, 11.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 10.5ms
# Speed: 2.8ms preprocess, 10.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 12 persons, 2 cars, 9.4ms
# Speed: 3.2ms preprocess, 9.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.7ms
# Speed: 3.0ms preprocess, 8.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 12 persons, 2 cars, 11.8ms
# Speed: 2.8ms preprocess, 11.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 11.3ms
# ...
# Speed: 2.4ms preprocess, 13.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 2 cars, 17.7ms
# Speed: 2.7ms preprocess, 17.7ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 21.4ms
# Speed: 2.7ms preprocess, 21.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 3 cars, 18.5ms
# Speed: 11.4ms preprocess, 18.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 12.2ms
# Speed: 2.4ms preprocess, 12.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 2 cars, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 22.1ms
# Speed: 4.6ms preprocess, 22.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 3 cars, 20.2ms
# Speed: 2.6ms preprocess, 20.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 14.3ms
# Speed: 2.5ms preprocess, 14.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 3 cars, 21.4ms
# Speed: 2.8ms preprocess, 21.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 20.4ms
# Speed: 2.6ms preprocess, 20.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 3 cars, 12.2ms
# Speed: 2.9ms preprocess, 12.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 20.7ms
# Speed: 3.4ms preprocess, 20.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 3 cars, 14.8ms
# Speed: 5.5ms preprocess, 14.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 23.1ms
# Speed: 4.4ms preprocess, 23.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 3 cars, 9.2ms
# Speed: 2.6ms preprocess, 9.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.8ms
# Speed: 4.2ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 4 cars, 9.6ms
# Speed: 3.2ms preprocess, 9.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.5ms
# Speed: 2.5ms preprocess, 8.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 9 persons, 3 cars, 10.0ms
# Speed: 2.6ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.1ms
# Speed: 2.4ms preprocess, 9.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 8 persons, 5 cars, 9.4ms
# Speed: 2.7ms preprocess, 9.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 7.6ms
# Speed: 2.3ms preprocess, 7.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 4 cars, 10.0ms
# Speed: 3.5ms preprocess, 10.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 10.3ms
# Speed: 2.4ms preprocess, 10.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 10 persons, 5 cars, 9.7ms
# Speed: 2.8ms preprocess, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.2ms
# Speed: 2.9ms preprocess, 9.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 13 persons, 4 cars, 10.8ms
# Speed: 4.0ms preprocess, 10.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 10.4ms
# Speed: 3.0ms preprocess, 10.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 12 persons, 3 cars, 10.6ms
# Speed: 3.9ms preprocess, 10.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 11.5ms
# Speed: 4.1ms preprocess, 11.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 3 cars, 11.0ms
# Speed: 3.5ms preprocess, 11.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 11.7ms
# Speed: 2.9ms preprocess, 11.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 13 persons, 3 cars, 9.7ms
# Speed: 3.6ms preprocess, 9.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 10.0ms
# Speed: 4.8ms preprocess, 10.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 8 persons, 4 cars, 10.8ms
# Speed: 3.1ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 8.3ms
# Speed: 4.4ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
#
# 0: 384x640 11 persons, 3 cars, 13.7ms
# Speed: 3.4ms preprocess, 13.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 11.4ms
# Speed: 2.7ms preprocess, 11.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# -----------plate detected------------
# {'car': {'bbox': [588.8178960443158, 251.21693980996042, 1571.5034523902448, 879.1689874468805]}, 'license_plate': {'bbox': [978.9911499023438, 672.9830322265625, 1325.1566162109375, 794.1531982421875], 'text': 'CK989UX', 'bbox_score': 0.7794484496116638, 'text_score': 0.2426491348190462}}
# {'car': {'bbox': [585.467402072889, 257.4256454282107, 1459.829888450068, 828.5841205166886]}, 'license_plate': {'bbox': [891.61083984375, 637.218505859375, 1195.4681396484375, 737.9224853515625], 'text': 'CK989IX', 'bbox_score': 0.7486490607261658, 'text_score': 0.30550232072530514}}
# {'car': {'bbox': [575.605048898618, 261.05043620198205, 1425.8895542777123, 816.44609421505]}, 'license_plate': {'bbox': [861.0556640625, 626.8958129882812, 1166.28076171875, 735.0866088867188], 'text': 'CK989IX', 'bbox_score': 0.7756615877151489, 'text_score': 0.32661411803425605}}
# {'car': {'bbox': [569.9690944888914, 262.4251964322552, 1409.435646734973, 809.4444081434378]}, 'license_plate': {'bbox': [853.6446533203125, 625.1905517578125, 1144.61279296875, 729.3951416015625], 'text': 'CK989IX', 'bbox_score': 0.7364009618759155, 'text_score': 0.46683026793459714}}
# {'car': {'bbox': [564.5430672434027, 264.748524516134, 1393.40719798991, 805.8234425466728]}, 'license_plate': {'bbox': [838.549560546875, 620.8342895507812, 1129.0233154296875, 724.2740478515625], 'text': 'CK989IX', 'bbox_score': 0.7624099254608154, 'text_score': 0.7460239280783402}}
# {'car': {'bbox': [557.9174179818492, 264.47819107067676, 1383.1460461140414, 802.8624526238775]}, 'license_plate': {'bbox': [835.080322265625, 620.4976806640625, 1115.5118408203125, 721.11572265625], 'text': 'CK989IX', 'bbox_score': 0.7353384494781494, 'text_score': 0.5794831401912186}}
# {'car': {'bbox': [554.6805835579478, 265.34212877547924, 1363.1494280303402, 791.8117739884292]}, 'license_plate': {'bbox': [819.4641723632812, 618.889404296875, 1088.5126953125, 704.7091064453125], 'text': 'CK989HY', 'bbox_score': 0.6933324933052063, 'text_score': 0.3852751561653217}}
# {'car': {'bbox': [551.6364495747266, 267.0601626968633, 1352.6962594351548, 788.6660854097449]}, 'license_plate': {'bbox': [810.5553588867188, 613.704833984375, 1081.31005859375, 703.002197265625], 'text': 'CK989IX', 'bbox_score': 0.7151307463645935, 'text_score': 0.7638985570583101}}
# {'car': {'bbox': [549.5058815384148, 268.96626141012104, 1341.1248651802853, 784.7573957826705]}, 'license_plate': {'bbox': [804.9761352539062, 614.1798706054688, 1072.7596435546875, 701.3931884765625], 'text': 'CK989IX', 'bbox_score': 0.6993184089660645, 'text_score': 0.6244274190746696}}
# {'car': {'bbox': [549.3950047830864, 270.03320377821285, 1332.9149093892706, 780.5748659528766]}, 'license_plate': {'bbox': [798.1946411132812, 612.8526611328125, 1066.13916015625, 695.8637084960938], 'text': 'CK989IX', 'bbox_score': 0.7032699584960938, 'text_score': 0.4680733237685024}}
# {'car': {'bbox': [548.3970906721637, 271.7052038895762, 1323.9447468414437, 777.7409407366173]}, 'license_plate': {'bbox': [795.8944091796875, 610.9692993164062, 1053.561279296875, 697.6240234375], 'text': 'CK989IX', 'bbox_score': 0.7329429388046265, 'text_score': 0.864697665054039}}
# {'car': {'bbox': [548.6076324869437, 270.92822496001077, 1306.4361166636122, 768.6235743814887]}, 'license_plate': {'bbox': [791.3252563476562, 608.7211303710938, 1038.206787109375, 692.1806030273438], 'text': 'CK989IX', 'bbox_score': 0.7309126853942871, 'text_score': 0.6899300760442147}}
# {'car': {'bbox': [549.3821039106007, 271.5139405637301, 1299.1111344811115, 765.4192007117983]}, 'license_plate': {'bbox': [784.2132568359375, 606.4210205078125, 1029.01025390625, 689.825927734375], 'text': 'CK989IX', 'bbox_score': 0.7352753281593323, 'text_score': 0.24604810002440033}}
# {'car': {'bbox': [550.1975342201274, 271.90969542034793, 1291.1707311582782, 760.2978459630987]}, 'license_plate': {'bbox': [777.588134765625, 600.4535522460938, 1022.3955688476562, 684.5599365234375], 'text': 'CK989IX', 'bbox_score': 0.7389438152313232, 'text_score': 0.45572719919253063}}
# {'car': {'bbox': [-54.43241455945747, 382.0703352828066, 1529.2180508526408, 1062.499574119635]}, 'license_plate': {'bbox': [580.0861206054688, 867.2920532226562, 1023.0443115234375, 1000.9861450195312], 'text': 'EN55ERC', 'bbox_score': 0.7641749978065491, 'text_score': 0.29256104233073993}}
# {'car': {'bbox': [-51.862133014332926, 385.8080299979676, 1466.4704365612479, 1061.3729477917154]}, 'license_plate': {'bbox': [554.875732421875, 834.4619750976562, 978.8604736328125, 972.1093139648438], 'text': 'EN555RC', 'bbox_score': 0.7905036211013794, 'text_score': 0.28205170037811067}}
# {'car': {'bbox': [-48.76011342416939, 387.3847929539511, 1405.8011103770223, 1059.5777936461454]}, 'license_plate': {'bbox': [531.1630859375, 815.1221923828125, 932.5625, 948.372802734375], 'text': 'EN355RG', 'bbox_score': 0.7710301280021667, 'text_score': 0.8475720879717595}}
# {'car': {'bbox': [98.77918856495171, 443.760362858568, 1234.3193684863652, 1019.7317086008536]}, 'license_plate': {'bbox': [525.6744384765625, 743.074951171875, 872.692626953125, 857.4296264648438], 'text': 'FN355RC', 'bbox_score': 0.7448597550392151, 'text_score': 0.45176345498067677}}
# {'car': {'bbox': [223.7286870593059, 384.174953249488, 1219.8467090660827, 962.2451094922701]}, 'license_plate': {'bbox': [574.7030029296875, 700.3236694335938, 863.469482421875, 795.1920776367188], 'text': 'EN355RG', 'bbox_score': 0.7229751348495483, 'text_score': 0.6881544766510308}}
# {'car': {'bbox': [260.123062669264, 384.1058537901575, 1208.308217012869, 937.1053720920047]}, 'license_plate': {'bbox': [578.23486328125, 683.8682861328125, 868.09912109375, 782.7669677734375], 'text': 'EN355RG', 'bbox_score': 0.7636237144470215, 'text_score': 0.6015663811326257}}
# {'car': {'bbox': [294.61972160348597, 383.7878425085883, 1201.07032392838, 914.799635637273]}, 'license_plate': {'bbox': [607.2105712890625, 672.1551513671875, 869.844970703125, 766.243896484375], 'text': 'EN355RG', 'bbox_score': 0.7571849226951599, 'text_score': 0.6226702302092326}}
# {'car': {'bbox': [328.3824007606636, 383.8530124779789, 1195.2233651616525, 893.474944198523]}, 'license_plate': {'bbox': [614.6109008789062, 662.0180053710938, 872.7655029296875, 754.5737915039062], 'text': 'EN355RG', 'bbox_score': 0.7263456583023071, 'text_score': 0.6642742924765417}}
# {'car': {'bbox': [395.1791387654047, 387.4273064366686, 1193.4207986093907, 857.5646065605644]}, 'license_plate': {'bbox': [655.579345703125, 645.6588134765625, 898.7421875, 727.691650390625], 'text': 'EN355RG', 'bbox_score': 0.7542935609817505, 'text_score': 0.5681777199665347}}
# {'car': {'bbox': [428.99310150635205, 384.74809882941776, 1194.594155255336, 836.5462137049228]}, 'license_plate': {'bbox': [678.6808471679688, 632.5321044921875, 907.2322998046875, 718.3059692382812], 'text': 'EN355RG', 'bbox_score': 0.7405153512954712, 'text_score': 0.5218984242719684}}
# {'car': {'bbox': [458.89795876992815, 384.59543904167197, 1198.8060303584946, 823.3069300146498]}, 'license_plate': {'bbox': [701.0604858398438, 624.60400390625, 915.047607421875, 704.2176513671875], 'text': 'EN355RG', 'bbox_score': 0.7256535291671753, 'text_score': 0.6125219516895244}}
# {'car': {'bbox': [489.52725572539237, 383.8311046490886, 1204.3966815537574, 807.7392733201467]}, 'license_plate': {'bbox': [720.1776123046875, 616.9575805664062, 926.7471313476562, 695.32177734375], 'text': 'EN355RG', 'bbox_score': 0.7500823140144348, 'text_score': 0.6821651834752013}}
# {'car': {'bbox': [518.275973950603, 383.72548914414904, 1208.4583984133294, 791.9030258289296]}, 'license_plate': {'bbox': [738.9669799804688, 608.7230224609375, 938.5955200195312, 680.8936767578125], 'text': 'EN355RG', 'bbox_score': 0.7115724682807922, 'text_score': 0.5061054153874204}}
# {'car': {'bbox': [571.0369183461542, 384.7078080119155, 1218.7597671409228, 766.9864762793997]}, 'license_plate': {'bbox': [778.9180908203125, 596.521240234375, 958.087158203125, 667.250732421875], 'text': 'EN355RG', 'bbox_score': 0.7452466487884521, 'text_score': 0.3815054078984128}}
# {'car': {'bbox': [595.1296952651669, 384.68873879219893, 1225.0794397736524, 755.908130238831]}, 'license_plate': {'bbox': [794.97216796875, 589.7462768554688, 972.973388671875, 658.595947265625], 'text': 'EN555RG', 'bbox_score': 0.7046924829483032, 'text_score': 0.387914432215996}}
# {'car': {'bbox': [619.4164633467951, 383.89914189900765, 1232.8435572381536, 745.8237762636402]}, 'license_plate': {'bbox': [815.527587890625, 578.6328125, 985.3526000976562, 653.7562255859375], 'text': 'EN355RG', 'bbox_score': 0.7187709808349609, 'text_score': 0.415835123430677}}
# {'car': {'bbox': [643.3899624011946, 382.13961052968654, 1242.3102292932517, 734.4574410534469]}, 'license_plate': {'bbox': [828.005859375, 575.070068359375, 1000.5069580078125, 649.0167236328125], 'text': 'EN355RG', 'bbox_score': 0.7365216612815857, 'text_score': 0.7818702783583784}}
# {'car': {'bbox': [667.488423891079, 383.55246598561394, 1252.0275704005146, 726.015237282551]}, 'license_plate': {'bbox': [847.484619140625, 570.505126953125, 1013.5931396484375, 636.3301391601562], 'text': 'EN355RG', 'bbox_score': 0.7052828073501587, 'text_score': 0.5855331183854893}}
# {'car': {'bbox': [689.8882483263421, 382.5984097882573, 1261.647840216795, 717.1878137741361]}, 'license_plate': {'bbox': [863.6927490234375, 570.7322387695312, 1027.7783203125, 633.708984375], 'text': 'EN355RG', 'bbox_score': 0.7057125568389893, 'text_score': 0.4639077577445383}}
# {'car': {'bbox': [710.3602833536866, 381.2632860765584, 1271.6888261352904, 708.3125038706639]}, 'license_plate': {'bbox': [878.3499755859375, 565.0228271484375, 1036.3414306640625, 628.585693359375], 'text': 'EN355RG', 'bbox_score': 0.702028214931488, 'text_score': 0.48645133542203567}}
# {'car': {'bbox': [822.9112069458824, 346.67007959312303, 1348.2556611255059, 657.9744493598669]}, 'license_plate': {'bbox': [984.2486572265625, 522.2726440429688, 1117.8944091796875, 583.7935180664062], 'text': 'EH355RG', 'bbox_score': 0.7157869338989258, 'text_score': 0.19704875557008217}}

# %%
import csv
import numpy as np
from scipy.interpolate import interp1d


def interpolate_bounding_boxes(data):
    # Extract necessary data columns from input data
    frame_numbers = np.array([int(row['frame_nmr']) for row in data])
    car_ids = np.array([int(float(row['car_id'])) for row in data])
    car_bboxes = np.array([list(map(float, row['car_bbox'][1:-1].split())) for row in data])
    license_plate_bboxes = np.array([list(map(float, row['license_plate_bbox'][1:-1].split())) for row in data])

    interpolated_data = []
    unique_car_ids = np.unique(car_ids)
    for car_id in unique_car_ids:

        frame_numbers_ = [p['frame_nmr'] for p in data if int(float(p['car_id'])) == int(float(car_id))]
        print(frame_numbers_, car_id)

        # Filter data for a specific car ID
        car_mask = car_ids == car_id
        car_frame_numbers = frame_numbers[car_mask]
        car_bboxes_interpolated = []
        license_plate_bboxes_interpolated = []

        first_frame_number = car_frame_numbers[0]
        last_frame_number = car_frame_numbers[-1]

        for i in range(len(car_bboxes[car_mask])):
            frame_number = car_frame_numbers[i]
            car_bbox = car_bboxes[car_mask][i]
            license_plate_bbox = license_plate_bboxes[car_mask][i]

            if i > 0:
                prev_frame_number = car_frame_numbers[i-1]
                prev_car_bbox = car_bboxes_interpolated[-1]
                prev_license_plate_bbox = license_plate_bboxes_interpolated[-1]

                if frame_number - prev_frame_number > 1:
                    # Interpolate missing frames' bounding boxes
                    frames_gap = frame_number - prev_frame_number
                    x = np.array([prev_frame_number, frame_number])
                    x_new = np.linspace(prev_frame_number, frame_number, num=frames_gap, endpoint=False)
                    interp_func = interp1d(x, np.vstack((prev_car_bbox, car_bbox)), axis=0, kind='linear')
                    interpolated_car_bboxes = interp_func(x_new)
                    interp_func = interp1d(x, np.vstack((prev_license_plate_bbox, license_plate_bbox)), axis=0, kind='linear')
                    interpolated_license_plate_bboxes = interp_func(x_new)

                    car_bboxes_interpolated.extend(interpolated_car_bboxes[1:])
                    license_plate_bboxes_interpolated.extend(interpolated_license_plate_bboxes[1:])

            car_bboxes_interpolated.append(car_bbox)
            license_plate_bboxes_interpolated.append(license_plate_bbox)

        for i in range(len(car_bboxes_interpolated)):
            frame_number = first_frame_number + i
            row = {}
            row['frame_nmr'] = str(frame_number)
            row['car_id'] = str(car_id)
            row['car_bbox'] = ' '.join(map(str, car_bboxes_interpolated[i]))
            row['license_plate_bbox'] = ' '.join(map(str, license_plate_bboxes_interpolated[i]))

            if str(frame_number) not in frame_numbers_:
                # Imputed row, set the following fields to '0'
                row['license_plate_bbox_score'] = '0'
                row['license_number'] = '0'
                row['license_number_score'] = '0'
            else:
                # Original row, retrieve values from the input data if available
                original_row = [p for p in data if int(p['frame_nmr']) == frame_number and int(float(p['car_id'])) == int(float(car_id))][0]
                row['license_plate_bbox_score'] = original_row['license_plate_bbox_score'] if 'license_plate_bbox_score' in original_row else '0'
                row['license_number'] = original_row['license_number'] if 'license_number' in original_row else '0'
                row['license_number_score'] = original_row['license_number_score'] if 'license_number_score' in original_row else '0'

            interpolated_data.append(row)

    return interpolated_data


# Load the CSV file
with open('test.csv', 'r') as file:
    reader = csv.DictReader(file)
    data = list(reader)

# Interpolate missing data
interpolated_data = interpolate_bounding_boxes(data)

# Write updated data to a new CSV file
header = ['frame_nmr', 'car_id', 'car_bbox', 'license_plate_bbox', 'license_plate_bbox_score', 'license_number', 'license_number_score']
with open('test_interpolated.csv', 'w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=header)
    writer.writeheader()
    writer.writerows(interpolated_data)
# Out:
# ['12'] 218
# ['21', '23', '24', '25'] 219
# ['26', '28', '29', '30', '31', '32', '34', '35', '36'] 220
# ['110', '111', '112'] 230
# ['116'] 236
# ['119', '120', '121', '122', '124', '125', '126', '127', '128', '130', '131', '132', '133', '134', '135', '136'] 237
# ['143'] 240

# %%
import ast

import cv2
import numpy as np
import pandas as pd


def draw_border(img, top_left, bottom_right, color=(0, 255, 0), thickness=10, line_length_x=200, line_length_y=200):
    x1, y1 = top_left
    x2, y2 = bottom_right

    cv2.line(img, (x1, y1), (x1, y1 + line_length_y), color, thickness)  #-- top-left
    cv2.line(img, (x1, y1), (x1 + line_length_x, y1), color, thickness)

    cv2.line(img, (x1, y2), (x1, y2 - line_length_y), color, thickness)  #-- bottom-left
    cv2.line(img, (x1, y2), (x1 + line_length_x, y2), color, thickness)

    cv2.line(img, (x2, y1), (x2 - line_length_x, y1), color, thickness)  #-- top-right
    cv2.line(img, (x2, y1), (x2, y1 + line_length_y), color, thickness)

    cv2.line(img, (x2, y2), (x2, y2 - line_length_y), color, thickness)  #-- bottom-right
    cv2.line(img, (x2, y2), (x2 - line_length_x, y2), color, thickness)

    return img


results = pd.read_csv('./test_interpolated.csv')

# load video
video_path = 'sample11.mp4'
cap = cv2.VideoCapture(video_path)

fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Specify the codec
fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter('./out.mp4', fourcc, fps, (width, height))

license_plate = {}
for car_id in np.unique(results['car_id']):
    max_ = np.amax(results[results['car_id'] == car_id]['license_number_score'])
    license_plate[car_id] = {'license_crop': None,
                             'license_plate_number': results[(results['car_id'] == car_id) &
                                                             (results['license_number_score'] == max_)]['license_number'].iloc[0]}
    cap.set(cv2.CAP_PROP_POS_FRAMES, results[(results['car_id'] == car_id) &
                                             (results['license_number_score'] == max_)]['frame_nmr'].iloc[0])
    ret, frame = cap.read()

    x1, y1, x2, y2 = ast.literal_eval(results[(results['car_id'] == car_id) &
                                              (results['license_number_score'] == max_)]['license_plate_bbox'].iloc[0].replace('[ ', '[').replace('   ', ' ').replace('  ', ' ').replace(' ', ','))

    license_crop = frame[int(y1):int(y2), int(x1):int(x2), :]
    license_crop = cv2.resize(license_crop, (int((x2 - x1) * 400 / (y2 - y1)), 400))

    license_plate[car_id]['license_crop'] = license_crop


frame_nmr = -1

cap.set(cv2.CAP_PROP_POS_FRAMES, 0)

# read frames
ret = True
while ret:
    ret, frame = cap.read()
    frame_nmr += 1
    if ret:
        df_ = results[results['frame_nmr'] == frame_nmr]
        for row_indx in range(len(df_)):
            # draw car
            car_x1, car_y1, car_x2, car_y2 = ast.literal_eval(df_.iloc[row_indx]['car_bbox'].replace('[ ', '[').replace('   ', ' ').replace('  ', ' ').replace(' ', ','))
            draw_border(frame, (int(car_x1), int(car_y1)), (int(car_x2), int(car_y2)), (0, 255, 0), 25,
                        line_length_x=200, line_length_y=200)

            # draw license plate
            x1, y1, x2, y2 = ast.literal_eval(df_.iloc[row_indx]['license_plate_bbox'].replace('[ ', '[').replace('   ', ' ').replace('  ', ' ').replace(' ', ','))
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 0, 255), 12)

            # crop license plate
            license_crop = license_plate[df_.iloc[row_indx]['car_id']]['license_crop']

            H, W, _ = license_crop.shape

            try:
                frame[int(car_y1) - H - 100:int(car_y1) - 100,
                      int((car_x2 + car_x1 - W) / 2):int((car_x2 + car_x1 + W) / 2), :] = license_crop

                frame[int(car_y1) - H - 400:int(car_y1) - H - 100,
                      int((car_x2 + car_x1 - W) / 2):int((car_x2 + car_x1 + W) / 2), :] = (255, 255, 255)

                (text_width, text_height), _ = cv2.getTextSize(
                    license_plate[df_.iloc[row_indx]['car_id']]['license_plate_number'],
                    cv2.FONT_HERSHEY_SIMPLEX,
                    4.3,
                    17)

                cv2.putText(frame,
                            license_plate[df_.iloc[row_indx]['car_id']]['license_plate_number'],
                            (int((car_x2 + car_x1 - text_width) / 2), int(car_y1 - H - 250 + (text_height / 2))),
                            cv2.FONT_HERSHEY_SIMPLEX,
                            4.3,
                            (0, 0, 0),
                            17)

            except:
                pass

        out.write(frame)
        frame = cv2.resize(frame, (1280, 720))

        # cv2.imshow('frame', frame)
        # cv2.waitKey(0)

out.release()
cap.release()
